# %%
import psycopg2

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

# %%
import psycopg2

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Create the employee table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS employees (
            id SERIAL PRIMARY KEY,
            name VARCHAR(255),
            age INTEGER,
            department VARCHAR(255),
            salary DECIMAL(10, 2)
        )
    ''')

    # Insert 10 rows of employee information
    employees = [
        (1, 'John Doe', 30, 'Sales', 50000.0),
        (2, 'Jane Smith', 35, 'Marketing', 60000.0),
        (3, 'Michael Johnson', 28, 'Finance', 55000.0),
        (4, 'Emily Davis', 32, 'HR', 52000.0),
        (5, 'Robert Wilson', 40, 'Operations', 70000.0),
        (6, 'Sarah Thompson', 27, 'Sales', 48000.0),
        (7, 'David Brown', 33, 'Marketing', 58000.0),
        (8, 'Jennifer Lee', 29, 'Finance', 53000.0),
        (9, 'Christopher Martin', 31, 'HR', 51000.0),
        (10, 'Jessica Taylor', 38, 'Operations', 65000.0)
    ]

    cursor.executemany('''
        INSERT INTO employees (id, name, age, department, salary)
        VALUES (%s, %s, %s, %s, %s)
    ''', employees)

    # Commit the changes to the database
    conn.commit()

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# /tmp/ipykernel_11397/547222927.py in <module>
#       1 try:
#       2     # Create a cursor object
# ----> 3     cursor = conn.cursor()
#       4
#       5     # Create the employee table
#
# InterfaceError: connection already closed

# %%
# Create the employee table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS employees (
        id SERIAL PRIMARY KEY,
        name VARCHAR(255),
        age INTEGER,
        department VARCHAR(255),
        salary DECIMAL(10, 2)
    )
''')

# Insert 10 rows of employee information
employees = [
    (1, 'John Doe', 30, 'Sales', 50000.0),
    (2, 'Jane Smith', 35, 'Marketing', 60000.0),
    (3, 'Michael Johnson', 28, 'Finance', 55000.0),
    (4, 'Emily Davis', 32, 'HR', 52000.0),
    (5, 'Robert Wilson', 40, 'Operations', 70000.0),
    (6, 'Sarah Thompson', 27, 'Sales', 48000.0),
    (7, 'David Brown', 33, 'Marketing', 58000.0),
    (8, 'Jennifer Lee', 29, 'Finance', 53000.0),
    (9, 'Christopher Martin', 31, 'HR', 51000.0),
    (10, 'Jessica Taylor', 38, 'Operations', 65000.0)
]

cursor.executemany('''
    INSERT INTO employees (id, name, age, department, salary)
    VALUES (%s, %s, %s, %s, %s)
''', employees)

# Commit the changes to the database
conn.commit()

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# /tmp/ipykernel_5765/3992416828.py in <module>
#       1 # Create the employee table
# ----> 2 cursor.execute('''
#       3     CREATE TABLE IF NOT EXISTS employees (
#       4         id SERIAL PRIMARY KEY,
#       5         name VARCHAR(255),
#
# InterfaceError: cursor already closed

# %%
import psycopg2

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()
try:
    # Create the employee table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS employees (
            id SERIAL PRIMARY KEY,
            name VARCHAR(255),
            age INTEGER,
            department VARCHAR(255),
            salary DECIMAL(10, 2)
        )
    ''')

    # Insert 10 rows of employee information
    employees = [
        (1, 'John Doe', 30, 'Sales', 50000.0),
        (2, 'Jane Smith', 35, 'Marketing', 60000.0),
        (3, 'Michael Johnson', 28, 'Finance', 55000.0),
        (4, 'Emily Davis', 32, 'HR', 52000.0),
        (5, 'Robert Wilson', 40, 'Operations', 70000.0),
        (6, 'Sarah Thompson', 27, 'Sales', 48000.0),
        (7, 'David Brown', 33, 'Marketing', 58000.0),
        (8, 'Jennifer Lee', 29, 'Finance', 53000.0),
        (9, 'Christopher Martin', 31, 'HR', 51000.0),
        (10, 'Jessica Taylor', 38, 'Operations', 65000.0)
    ]

    cursor.executemany('''
        INSERT INTO employees (id, name, age, department, salary)
        VALUES (%s, %s, %s, %s, %s)
    ''', employees)

    # Commit the changes to the database
    conn.commit()

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()

# %%
import psycopg2
import openai

# Set your OpenAI API key
openai.api_key = "k-Zal52g3n1VBxJ1b4KvFAT3BlbkFJi8TDRbpag8jgLKLAmfoU"

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

try:
    # Fetch the table schema
    cursor.execute("SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'employees'")
    schema_rows = cursor.fetchall()
    schema = {row[0]: row[1] for row in schema_rows}

    # Generate SQL query using OpenAI
    prompt = "Generate a SQL query to retrieve data from the employees table."
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50,
        n=1,
        stop=None,
        temperature=0.5,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0
    )
    sql_query = response.choices[0].text.strip()

    # Generate natural language question and answer using OpenAI
    prompt = "Ask a question about the employees table:\n\nQ:"
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50,
        n=1,
        stop=None,
        temperature=0.5,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0
    )
    question = response.choices[0].text.strip()

    prompt = f"Q: {question}\n\nA:"
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50,
        n=1,
        stop=None,
        temperature=0.5,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0
    )
    answer = response.choices[0].text.strip()

    # Print the generated SQL query, question, and answer
    print("Generated SQL Query:")
    print(sql_query)
    print("\nGenerated Question:")
    print(question)
    print("\nGenerated Answer:")
    print(answer)

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_5765/901335521.py in <module>
#      24     # Generate SQL query using OpenAI
#      25     prompt = "Generate a SQL query to retrieve data from the employees table."
# ---> 26     response = openai.Completion.create(
#      27         engine="text-davinci-003",
#      28         prompt=prompt,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     113         )
#     114         url = cls.class_url(engine, api_type, api_version)
# --> 115         response, _, api_key = requestor.request(
#     116             "post",
#     117             url,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     179             request_timeout=request_timeout,
#     180         )
# --> 181         resp, got_stream = self._interpret_response(result, stream)
#     182         return resp, got_stream, self.api_key
#     183
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     394         else:
#     395             return (
# --> 396                 self._interpret_response_line(
#     397                     result.content, result.status_code, result.headers, stream=False
#     398                 ),
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427         stream_error = stream and "error" in resp.data
#     428         if stream_error or not 200 <= rcode < 300:
# --> 429             raise self.handle_error_response(
#     430                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431             )
#
# AuthenticationError: Incorrect API key provided: k-Zal52g**************************************mfoU. You can find your API key at https://platform.openai.com/account/api-keys.
