# %%
import psycopg2

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()
try:
    # Create the employee table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS employees (
            id SERIAL PRIMARY KEY,
            name VARCHAR(255),
            age INTEGER,
            department VARCHAR(255),
                   
            salary DECIMAL(10, 2)
        )
    ''')

    # Insert 10 rows of employee information
    employees = [
        (1, 'John Doe', 30, 'Sales', 50000.0),
        (2, 'Jane Smith', 35, 'Marketing', 60000.0),
        (3, 'Michael Johnson', 28, 'Finance', 55000.0),
        (4, 'Emily Davis', 32, 'HR', 52000.0),
        (5, 'Robert Wilson', 40, 'Operations', 70000.0),
        (6, 'Sarah Thompson', 27, 'Sales', 48000.0),
        (7, 'David Brown', 33, 'Marketing', 58000.0),
        (8, 'Jennifer Lee', 29, 'Finance', 53000.0),
        (9, 'Christopher Martin', 31, 'HR', 51000.0),
        (10, 'Jessica Taylor', 38, 'Operations', 65000.0)
    ]

    cursor.executemany('''
        INSERT INTO employees (id, name, age, department, salary)
        VALUES (%s, %s, %s, %s, %s)
    ''', employees)

    # Commit the changes to the database
    conn.commit()

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()

# %%
import psycopg2
import openai

# Set your OpenAI API key
#openai.api_key = "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"
openai.api_key = "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"
# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

try:
    # Fetch the table schema
    cursor.execute("SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'employees'")
    schema_rows = cursor.fetchall()
    schema = {row[0]: row[1] for row in schema_rows}

    # Generate SQL query using OpenAI
    prompt = "Generate a SQL query to retrieve data from the employees table."
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50,
        n=1,
        stop=None,
        temperature=0.5,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0
    )
    sql_query = response.choices[0].text.strip()

    # Generate natural language question and answer using OpenAI
    prompt = "Ask a question about the employees table:\n\nQ:"
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50,
        n=1,
        stop=None,
        temperature=0.5,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0
    )
    question = response.choices[0].text.strip()

    prompt = f"Q: {question}\n\nA:"
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=50,
        n=1,
        stop=None,
        temperature=0.5,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0
    )
    answer = response.choices[0].text.strip()

    # Print the generated SQL query, question, and answer
    print("Generated SQL Query:")
    print(sql_query)
    print("\nGenerated Question:")
    print(question)
    print("\nGenerated Answer:")
    print(answer)

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Generated SQL Query:
# SELECT * FROM employees;
#
# Generated Question:
# What is the average age of employees in the table?
#
# Generated Answer:
# The average age of employees in the table is 45.

# %%
import psycopg2
import openai

# Set your OpenAI API key
openai.api_key = "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"
#openai.api_key = openai.api_key = "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"
# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

try:
    # Fetch the table schema
    cursor.execute("SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'employees'")
    schema_rows = cursor.fetchall()
    schema = {row[0]: row[1] for row in schema_rows}

    while True:
        # Prompt for a question or enter 'exit' to end the conversation
        question = input("Enter a question or type 'exit' to end the conversation: ")

        if question.lower() == "exit":
            break

        # Generate SQL query using OpenAI
        prompt = f"Retrieve data from the 'employees' table based on the question: {question}."
        response = openai.Completion.create(
            engine="text-davinci-003",
            prompt=prompt,
            max_tokens=50,
            n=1,
            stop=None,
            temperature=0.5,
            top_p=1.0,
            frequency_penalty=0.0,
            presence_penalty=0.0
        )
        sql_query = response.choices[0].text.strip()

        # Execute the SQL query
        cursor.execute(sql_query)
        result = cursor.fetchall()

        # Print the question, SQL query, SQL result, and answer
        print("Question:", question)
        print("SQL Query:", sql_query)
        print("SQL Result:", result)
        print("Answer:", response.choices[0].text.strip())

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Question: what are the toal number of employees
# SQL Query: SELECT COUNT(*) FROM employees;
# SQL Result: [(10,)]
# Answer: SELECT COUNT(*) FROM employees;

# %%
import psycopg2
from psycopg2 import sql

# PostgreSQL connection details
host = "localhost"
database = "employee"
user = "postgres"
password = "7"
table_name = 'youtubevide'
csv_file = 'city_chart.csv'
# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(host=host, database=database, user=user, password=password)

# Create a cursor object to interact with the database
cursor = conn.cursor()

# Create the table if it doesn't exist
create_table_sql = """
CREATE TABLE IF NOT EXISTS {} (
    date DATE,
    city_id VARCHAR(255),
    city_name VARCHAR(255),
    views INTEGER
);
""".format(table_name)
cursor.execute(create_table_sql)

# Truncate the table if needed
cursor.execute(sql.SQL("TRUNCATE {} RESTART IDENTITY;").format(sql.Identifier(table_name)))

# Prepare the INSERT statement
insert_sql = sql.SQL("INSERT INTO {} (date, city_id, city_name, views) VALUES (%s, %s, %s, %s);").format(sql.Identifier(table_name))

# Read the CSV file and insert the data row by row
with open(csv_file, 'r') as file:
    next(file)  # Skip the header row
    for line in file:
        data = line.strip().split(',')
        cursor.execute(insert_sql, data)

# Commit the changes
conn.commit()

# Close the cursor and database connection
cursor.close()
conn.close()

print("CSV file imported successfully into the PostgreSQL table.")
# Out:
# CSV file imported successfully into the PostgreSQL table.

# %%
import psycopg2
import openai

# Set your OpenAI API key
openai.api_key = "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"
#openai.api_key = openai.api_key = "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"
# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

try:
    # Fetch the table schema
    cursor.execute("SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'youtubevide'")
    schema_rows = cursor.fetchall()
    schema = {row[0]: row[1] for row in schema_rows}

    while True:
        # Prompt for a question or enter 'exit' to end the conversation
        question = input("Enter a question or type 'exit' to end the conversation: ")

        if question.lower() == "exit":
            break

        # Generate SQL query using OpenAI
        prompt = f"Retrieve data from the 'youtubevide' table based on the question: {question}."
        response = openai.Completion.create(
            engine="text-davinci-003",
            prompt=prompt,
            max_tokens=50,
            n=1,
            stop=None,
            temperature=0.5,
            top_p=1.0,
            frequency_penalty=0.0,
            presence_penalty=0.0
        )
        sql_query = response.choices[0].text.strip()

        # Execute the SQL query
        cursor.execute(sql_query)
        result = cursor.fetchall()

        # Print the question, SQL query, SQL result, and answer
        print("Question:", question)
        print("SQL Query:", sql_query)
        print("SQL Result:", result)
        print("Answer:", response.choices[0].text.strip())

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Question: what about total number who  city_name  is  Addis Ababa
# SQL Query: SELECT COUNT(*) FROM youtubevide WHERE city_name = 'Addis Ababa';
# SQL Result: [(1279,)]
# Answer: SELECT COUNT(*) FROM youtubevide WHERE city_name = 'Addis Ababa';

# %%
city_name  | views 
------------+---------------------------------------+-------------+-------
 2020-06-28 | 0x164b85cef5ab402d:0x8467b6b037a24d49 | Addis Ababa
# Out:
#   File "/tmp/ipykernel_17018/970592138.py", line 2
#     ------------+---------------------------------------+-------------+-------
#                                                                               ^
# SyntaxError: invalid syntax

# %%
import psycopg2
from sqlalchemy import create_engine

class ConnectToPostgres:
    def __init__(self):
        db_params = {
            'host': 'localhost',
            'user': 'postgres',
            'port': '5432',
             'password':"7",
            'database': 'employees'
        }

        try:
            # Create a PostgreSQL database engine
            self.engine = create_engine(f"postgresql+psycopg2://{db_params['user']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")
        except Exception as error:
            raise Exception("Cannot connect to the database. Please check your connection details.")

    def get_engine(self):
        return self.engine

# %%
import psycopg2
from sqlalchemy import create_engine, Column, Integer, String, Float, Date, ForeignKey
from sqlalchemy.orm import declarative_base

class ConnectToPostgres:
    def __init__(self):
        db_params = {
            'host': 'localhost',
            'user': 'postgres',
            'port': '5432',
            'password': '7',
            'database': 'employee'
        }

        try:
            # Create a PostgreSQL database engine
            self.engine = create_engine(f"postgresql+psycopg2://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")
        except Exception as error:
            raise Exception("Cannot connect to the database. Please check your connection details.")

    def get_engine(self):
        return self.engine

Base = declarative_base()

class CityChart(Base):
    __tablename__ = 'city_chart'
    date = Column('date', Date, primary_key=True)
    city_id = Column('city_id', String)
    city_name = Column('city_name', String)
    views = Column('views', Integer)

    def __init__(self, date, city_id, city_name, views):
        self.date = date
        self.city_id = city_id
        self.city_name = city_name
        self.views = views
      
class ContentTypeInfo(Base):
    __tablename__ = "content_type_info"

    id = Column("id", Integer, primary_key=True)
    content_type = Column("content_type", String)
    watch_time = Column("watch_time_in_hours", Integer)
    average_time_duration = Column("average_time_duration", String)

    def __init__(self, content_type, watch_time, average_time_duration):
        self.content_type = content_type
        self.watch_time = watch_time
        self.average_time_duration = average_time_duration

class ContentTypeChart(Base):
    __tablename__ = "content_type_chart"

    id = Column("id", Integer, primary_key=True)
    date = Column("date", Date)
    views = Column("views", Integer)
    content_types = Column(Integer, ForeignKey("content_type_info.id"))

    def __init__(self, date, views, content_types):
        self.date = date
        self.views = views
        self.content_types = content_types

class DeviceTypeInfo(Base):
    __tablename__ = "device_type_info"

    id = Column("id", Integer, primary_key=True)
    device_type = Column("device_type", String)
    watch_time = Column("watch_time_in_hours", Integer)
    average_time_duration = Column("average_time_duration", String)

    def __init__(self, device_type, watch_time, average_time_duration):
        self.device_type = device_type
        self.watch_time = watch_time
        self.average_time_duration = average_time_duration

class DeviceTypeChart(Base):
    __tablename__ = "device_type_chart"

    id = Column("id", Integer, primary_key=True)
    date = Column("date", Date)
    views = Column("views", Integer)
    device_types = Column(Integer, ForeignKey("device_type_info.id"))

    def __init__(self, date, views, device_types):
        self.date = date
        self.views = views
        self.device_types = device_types

conn = ConnectToPostgres()
engine = conn.get_engine()
Base.metadata.create_all(bind=engine, checkfirst=True)

# %%
home/aron/Desktop/city_table.csv

home/aron/Desktop/country_code.csv
home/aron/Desktop/city_table.csv

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/common_table.csv")

# %%
# Define the table name
table_name = 'common_table'

# Insert the DataFrame into the PostgreSQL table
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/city_table.csv")

# %%
# Define the table name
table_name = 'city_table'

# Insert the DataFrame into the PostgreSQL table
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/device_chart.csv")

# %%
table_name ='device_type_chart'

# %%
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/sharing_service.csv")

# %%
table_name ='sharing_service'

# %%
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/sharing_service.csv")

# %%
table_name ='sharing_service'

# %%
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_30628/679319484.py in <module>
# ----> 1 me/aron/Desktop/city_table.csv
#       2
#       3 home/aron/Desktop/country_code.csv
#       4 home/aron/Desktop/city_table.csv
#
# NameError: name 'me' is not defined

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/country_code.csv")
table_name ='city_table'
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
import pandas as pd
df = pd.read_csv(r"~/Desktop/Untitled_Message/country_code.csv")
table_name ='city_table'
df.to_sql(table_name, engine.connect(), index=False, if_exists='replace')

# %%
import psycopg2
import openai

# Set your OpenAI API key
openai.api_key = "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"
#openai.api_key = openai.api_key = "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"
# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    database="employee",
    user="postgres",
    password="7"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

try:
    # Fetch the table schema
    cursor.execute("SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'device_type_chart'")
    schema_rows = cursor.fetchall()
    schema = {row[0]: row[1] for row in schema_rows}

    while True:
        # Prompt for a question or enter 'exit' to end the conversation
        question = input("Enter a question or type 'exit' to end the conversation: ")

        if question.lower() == "exit":
            break

        # Generate SQL query using OpenAI
        prompt = f"Retrieve data from the 'device_type_chart' table based on the question: {question}."
        response = openai.Completion.create(
            engine="text-davinci-003",
            prompt=prompt,
            max_tokens=50,
            n=1,
            stop=None,
            temperature=0.5,
            top_p=1.0,
            frequency_penalty=0.0,
            presence_penalty=0.0
        )

        # to integrate into redash backend Api## misge
        sql_query = response.choices[0].text.strip()

        # Execute the SQL query
        cursor.execute(sql_query)
        result = cursor.fetchall()

        # Print the question, SQL query, SQL result, and answer
        print("Question:", question)
        print("SQL Query:", sql_query)
        print("SQL Result:", result)
        print("Answer:", response.choices[0].text.strip())

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Question: the ttal number of device
# SQL Query: SELECT COUNT(*) FROM device_type_chart;
# SQL Result: [(5116,)]
# Answer: SELECT COUNT(*) FROM device_type_chart;
